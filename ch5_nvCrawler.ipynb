# %%
import os
import sys
import urllib.request
import datetime
import time
import json

# %%
client_id = '7Utgf6h8KTm4NPjIimcv'
client_secret = 'ce3pg0F6sr'

def getRequestUrl(url):
  req = urllib.request.Request(url)
  req.add_header("X-Naver-Client-Id",client_id)
  req.add_header("X-Naver-Client-Secret",client_secret)

  try:
    response = urllib.request.urlopen(req)
    if response.getcode() == 200:
      print("[%s] Url Request Success" % datetime.datetime.now())
      return response.read().decode('utf-8')

  except Exception as e:
    print(e)
    print("[%s] Error for URL : %s" % (datetime.datetime.now(),url))
    return None


def getNaverSearch(node, srcText, start, display):
  base = "https://openapi.naver.com/v1/search"
  node = "/%s.json" %node
  parameters = "?query =%s&start = %s&didsplay = %s"%(urllib.parse.quote(srcText),start,display)

  url = base +node + parameters
  responseDecode = getRequestUrl(url)

  if (responseDecode == None):
    return None

  else:
    return json.loads(responseDecode)

def getPostData(post, jsonResult, cnt):
  title = post['title']
  description = post['description']
  org_link = post['originallink']
  link = post['link']

  pDate = dataetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S +0900')
  pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')

  jsonResult.append({'cnt':cnt, 'title':title, 'description':description,'orglink':org_link, 'link':org_linl, 'pDate':pDate})

  return


def main():
  node = 'news'
  srcText = input("검색어를 입력하세요:")
  cnt= 0
  jsonResult = []

  jsonResponse = getNaverSearch(node,srcText,1,100) #[code2]
  total = jsonResponse['total']

  while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
    for post in jsonResponse['items']:
      cnt += 1
      getPostData(post , jsonResult, cnt) #[code3]
    
    start = jsonResponse['start'] + jsonResponse['display']
    jsonResponse = getNaverSearch(node, srcText , start , 100) #[code2]

  print('전체 검색 : %d 건'%total)

  with open('%s_naver_%s.json' % (srcText,node), 'w' , encoding = 'utf8') as outfile:

    jsonFile = json.dumps(jsonResult, indent = 4, sort_keys = True,
                             ensure_ascil = False)
       
    outfile.write(jsonFile)
  print("가져온 데이터ㅣ %d 건" %(cnt))
  print('%s_naver_%s.json SAVED' % (srcText, node))


if __name__ == '__main__':
  main()
# Out:
# 검색어를 입력하세요:서예지
# URL can't contain control characters. '/v1/search/news.json?query =%EC%84%9C%EC%98%88%EC%A7%80&start = 1&didsplay = 100' (found at least ' ')
# [2021-04-13 17:11:20.250848] Error for URL : https://openapi.naver.com/v1/search/news.json?query =%EC%84%9C%EC%98%88%EC%A7%80&start = 1&didsplay = 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-54164e1a9a09> in <module>()
#      77
#      78 if __name__ == '__main__':
# ---> 79   main()
#
# <ipython-input-2-54164e1a9a09> in main()
#      54
#      55   jsonResponse = getNaverSearch(node,srcText,1,100) #[code2]
# ---> 56   total = jsonResponse['total']
#      57
#      58   while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
#
# TypeError: 'NoneType' object is not subscriptable
